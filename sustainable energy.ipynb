# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt

# %%
sus=pd.read_csv("global_data_on_sustainable_energy.csv")

# %%
sus.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
sus.shape
# Out:
# (3649, 21)

# %%
sus.describe()
# Out:
#               Year  Access to electricity (% of population)  \
# count  3649.000000                              3639.000000
# mean   2010.038367                                78.933702
# std       6.054228                                30.275541
# min    2000.000000                                 1.252269
# 25%    2005.000000                                59.800890
# 50%    2010.000000                                98.361570
# 75%    2015.000000                               100.000000
# max    2020.000000                               100.000000
#
#        Access to clean fuels for cooking  \
# count                        3480.000000
# mean                           63.255287
# std                            39.043658
# min                             0.000000
# 25%                            23.175000
# 50%                            83.150000
# 75%                           100.000000
# max                           100.000000
#
# ...

# %%
sus.isnull()
# Out:
#       Entity   Year  Access to electricity (% of population)  \
# 0      False  False                                    False
# 1      False  False                                    False
# 2      False  False                                    False
# 3      False  False                                    False
# 4      False  False                                    False
# ...      ...    ...                                      ...
# 3644   False  False                                    False
# 3645   False  False                                    False
# 3646   False  False                                    False
# 3647   False  False                                    False
# 3648   False  False                                    False
#
#       Access to clean fuels for cooking  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# ...

# %%
sus.dropna
# Out:
# <bound method DataFrame.dropna of            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# ...

# %%
sus.drop_duplicates()
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
sus.shape
# Out:
# (3649, 21)

# %%
sus.dtypes
# Out:
# Entity                                                               object
# Year                                                                  int64
# Access to electricity (% of population)                             float64
# Access to clean fuels for cooking                                   float64
# Renewable-electricity-generating-capacity-per-capita                float64
# Financial flows to developing countries (US $)                      float64
# Renewable energy share in the total final energy consumption (%)    float64
# Electricity from fossil fuels (TWh)                                 float64
# Electricity from nuclear (TWh)                                      float64
# Electricity from renewables (TWh)                                   float64
# Low-carbon electricity (% electricity)                              float64
# Primary energy consumption per capita (kWh/person)                  float64
# ...

# %% [markdown]
# ### What is the percentage of the population with access to electricity in each country and year?

# %%
access_to_electricity = sus[['Entity', 'Year', 'Access to electricity (% of population)']]
access_to_electricity
# Out:
#            Entity  Year  Access to electricity (% of population)
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
# [3649 rows x 3 columns]

# %%
clean_fuels_cooking = sus[['Entity', 'Year', 'Access to clean fuels for cooking']]
clean_fuels_cooking
# Out:
#            Entity  Year  Access to clean fuels for cooking
# 0     Afghanistan  2000                                6.2
# 1     Afghanistan  2001                                7.2
# 2     Afghanistan  2002                                8.2
# 3     Afghanistan  2003                                9.5
# 4     Afghanistan  2004                               10.9
# ...           ...   ...                                ...
# 3644     Zimbabwe  2016                               29.8
# 3645     Zimbabwe  2017                               29.8
# 3646     Zimbabwe  2018                               29.9
# 3647     Zimbabwe  2019                               30.1
# 3648     Zimbabwe  2020                               30.4
#
# [3649 rows x 3 columns]

# %% [markdown]
# ### What is the per capita renewable electricity generating capacity in each country and year?

# %%
renewable_capacity_per_capita = sus[['Entity', 'Year', 'Renewable-electricity-generating-capacity-per-capita']]
renewable_capacity_per_capita
# Out:
#            Entity  Year  Renewable-electricity-generating-capacity-per-capita
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# [3649 rows x 3 columns]

# %% [markdown]
# ### What is the renewable energy share in the total final energy consumption?

# %%
renewable_energy_share = sus[['Entity', 'Year', 'Renewable energy share in the total final energy consumption (%)']]
renewable_energy_share
# Out:
#            Entity  Year  \
# 0     Afghanistan  2000
# 1     Afghanistan  2001
# 2     Afghanistan  2002
# 3     Afghanistan  2003
# 4     Afghanistan  2004
# ...           ...   ...
# 3644     Zimbabwe  2016
# 3645     Zimbabwe  2017
# 3646     Zimbabwe  2018
# 3647     Zimbabwe  2019
# 3648     Zimbabwe  2020
#
#       Renewable energy share in the total final energy consumption (%)
# 0                                                 44.99
# 1                                                 45.60
# 2                                                 37.83
# 3                                                 36.66
# 4                                                 44.24
# ...                                                 ...
# 3644                                              81.90
# 3645                                              82.46
# 3646                                              80.23
# 3647                                              81.50
# ...

# %%
# 3. Electricity Generation
electricity_generation = sus[['Entity', 'Year', 'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)', 'Electricity from renewables (TWh)', 'Low-carbon electricity (% electricity)']]
electricity_generation
# Out:
#            Entity  Year  Electricity from fossil fuels (TWh)  \
# 0     Afghanistan  2000                                 0.16
# 1     Afghanistan  2001                                 0.09
# 2     Afghanistan  2002                                 0.13
# 3     Afghanistan  2003                                 0.31
# 4     Afghanistan  2004                                 0.33
# ...           ...   ...                                  ...
# 3644     Zimbabwe  2016                                 3.50
# 3645     Zimbabwe  2017                                 3.05
# 3646     Zimbabwe  2018                                 3.73
# 3647     Zimbabwe  2019                                 3.66
# 3648     Zimbabwe  2020                                 3.40
#
#       Electricity from nuclear (TWh)  Electricity from renewables (TWh)  \
# 0                                0.0                               0.31
# 1                                0.0                               0.50
# ...

# %%
# 4. Financial Flows
financial_flows = sus[['Entity', 'Year', 'Financial flows to developing countries (US $)']]
financial_flows
# Out:
#            Entity  Year  Financial flows to developing countries (US $)
# 0     Afghanistan  2000                                         20000.0
# 1     Afghanistan  2001                                        130000.0
# 2     Afghanistan  2002                                       3950000.0
# 3     Afghanistan  2003                                      25970000.0
# 4     Afghanistan  2004                                             NaN
# ...           ...   ...                                             ...
# 3644     Zimbabwe  2016                                         30000.0
# 3645     Zimbabwe  2017                                       5570000.0
# 3646     Zimbabwe  2018                                         10000.0
# 3647     Zimbabwe  2019                                        250000.0
# 3648     Zimbabwe  2020                                         30000.0
#
# [3649 rows x 3 columns]

# %%
# 5. Carbon Emissions
co2_emissions = sus[['Entity', 'Year', 'Value_co2_emissions_kt_by_country']]
co2_emissions
# Out:
#            Entity  Year  Value_co2_emissions_kt_by_country
# 0     Afghanistan  2000                         760.000000
# 1     Afghanistan  2001                         730.000000
# 2     Afghanistan  2002                        1029.999971
# 3     Afghanistan  2003                        1220.000029
# 4     Afghanistan  2004                        1029.999971
# ...           ...   ...                                ...
# 3644     Zimbabwe  2016                       11020.000460
# 3645     Zimbabwe  2017                       10340.000150
# 3646     Zimbabwe  2018                       12380.000110
# 3647     Zimbabwe  2019                       11760.000230
# 3648     Zimbabwe  2020                                NaN
#
# [3649 rows x 3 columns]

# %%
renewables_percentage_primary_energy = sus[['Entity', 'Year', 'Renewables (% equivalent primary energy)']]
renewables_percentage_primary_energy
# Out:
#            Entity  Year  Renewables (% equivalent primary energy)
# 0     Afghanistan  2000                                       NaN
# 1     Afghanistan  2001                                       NaN
# 2     Afghanistan  2002                                       NaN
# 3     Afghanistan  2003                                       NaN
# 4     Afghanistan  2004                                       NaN
# ...           ...   ...                                       ...
# 3644     Zimbabwe  2016                                       NaN
# 3645     Zimbabwe  2017                                       NaN
# 3646     Zimbabwe  2018                                       NaN
# 3647     Zimbabwe  2019                                       NaN
# 3648     Zimbabwe  2020                                       NaN
#
# [3649 rows x 3 columns]

# %%
# 6. Economic Indicators
gdp_growth = sus[['Entity', 'Year', 'gdp_growth']]
gdp_growth
# Out:
#            Entity  Year  gdp_growth
# 0     Afghanistan  2000         NaN
# 1     Afghanistan  2001         NaN
# 2     Afghanistan  2002         NaN
# 3     Afghanistan  2003    8.832278
# 4     Afghanistan  2004    1.414118
# ...           ...   ...         ...
# 3644     Zimbabwe  2016    0.755869
# 3645     Zimbabwe  2017    4.709492
# 3646     Zimbabwe  2018    4.824211
# 3647     Zimbabwe  2019   -6.144236
# 3648     Zimbabwe  2020   -6.248748
#
# [3649 rows x 3 columns]

# %%
gdp_per_capita = sus[['Entity', 'Year', 'gdp_per_capita']]
gdp_per_capita
# Out:
#            Entity  Year  gdp_per_capita
# 0     Afghanistan  2000             NaN
# 1     Afghanistan  2001             NaN
# 2     Afghanistan  2002      179.426579
# 3     Afghanistan  2003      190.683814
# 4     Afghanistan  2004      211.382074
# ...           ...   ...             ...
# 3644     Zimbabwe  2016     1464.588957
# 3645     Zimbabwe  2017     1235.189032
# 3646     Zimbabwe  2018     1254.642265
# 3647     Zimbabwe  2019     1316.740657
# 3648     Zimbabwe  2020     1214.509820
#
# [3649 rows x 3 columns]

# %%
# 7. Energy Consumption
energy_consumption = sus[['Entity', 'Year', 'Primary energy consumption per capita (kWh/person)', 'Energy intensity level of primary energy (MJ/$2017 PPP GDP)']]
energy_consumption
# Out:
#            Entity  Year  Primary energy consumption per capita (kWh/person)  \
# 0     Afghanistan  2000                                          302.59482
# 1     Afghanistan  2001                                          236.89185
# 2     Afghanistan  2002                                          210.86215
# 3     Afghanistan  2003                                          229.96822
# 4     Afghanistan  2004                                          204.23125
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                         3227.68020
# 3645     Zimbabwe  2017                                         3068.01150
# 3646     Zimbabwe  2018                                         3441.98580
# 3647     Zimbabwe  2019                                         3003.65530
# 3648     Zimbabwe  2020                                         2680.13180
#
#       Energy intensity level of primary energy (MJ/$2017 PPP GDP)
# ...

# %%
# 9. Comparative Analysis
highest_renewable_countries = sus.nlargest(5, 'Renewable energy share in the total final energy consumption (%)')
highest_renewable_countries
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 550    Burundi  2004                                 3.763859
# 551    Burundi  2005                                 3.207317
# 549    Burundi  2003                                 3.445382
# 1134  Ethiopia  2000                                12.700000
# 3420    Uganda  2002                                 7.800000
#
#       Access to clean fuels for cooking  \
# 550                                 0.3
# 551                                 0.3
# 549                                 0.3
# 1134                                0.9
# 3420                                0.9
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 550                                                7.61
# 551                                                7.38
# 549                                                7.85
# 1134                                               6.12
# 3420                                              11.96
# ...

# %%
lowest_renewable_countries = sus.nsmallest(5, 'Renewable energy share in the total final energy consumption (%)')
lowest_renewable_countries
# Out:
#                  Entity  Year  Access to electricity (% of population)  \
# 84  Antigua and Barbuda  2000                                97.689260
# 85  Antigua and Barbuda  2001                                97.785255
# 86  Antigua and Barbuda  2002                               100.000000
# 87  Antigua and Barbuda  2003                                97.956825
# 88  Antigua and Barbuda  2004                                98.037100
#
#     Access to clean fuels for cooking  \
# 84                              100.0
# 85                              100.0
# 86                              100.0
# 87                              100.0
# 88                              100.0
#
#     Renewable-electricity-generating-capacity-per-capita  \
# 84                                                0.0
# 85                                                0.0
# 86                                                0.0
# 87                                                0.0
# ...
